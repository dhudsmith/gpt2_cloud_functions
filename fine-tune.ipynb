# %%
import gpt_2_simple as gpt2
import os
import requests
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
sess = gpt2.tf.Session(config=gpt2.tf.ConfigProto(log_device_placement=True))
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5

# %%
model_name = "124M"
if not os.path.isdir(os.path.join("models", model_name)):
	print(f"Downloading {model_name} model...")
	gpt2.download_gpt2(model_name=model_name)   # model is saved into current directory under /models/124M/

# %%
file_name = "shakespeare.txt"
if not os.path.isfile(file_name):
	url = "https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt"
	data = requests.get(url)
	
	with open(file_name, 'w') as f:
		f.write(data.text)

# %%
sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
              file_name,
              model_name=model_name,
              steps=1000)   # steps is max number of training steps

gpt2.generate(sess)
# Out:
# WARNING:tensorflow:From /home/watson/anaconda3/lib/python3.7/site-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %% [markdown]
# # Trump

# %%
gpt2.reset_session(sess)
file_name = "trump.txt"
run_name = "run_trump"

# %%
sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
              file_name,
              run_name = run_name,
              model_name=model_name,
              steps=1000)   # steps is max number of training steps

gpt2.generate(sess)
# Out:
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]
# dataset has 256349 tokens
# Training...
# [1 | 6.49] loss=3.76 avg=3.76
# [2 | 7.48] loss=3.73 avg=3.75
# [3 | 8.49] loss=3.53 avg=3.67
# [4 | 9.51] loss=3.65 avg=3.67
# [5 | 10.52] loss=3.57 avg=3.65
# [6 | 11.54] loss=3.43 avg=3.61
# [7 | 12.55] loss=3.48 avg=3.59
# [8 | 13.57] loss=3.27 avg=3.55
# [9 | 14.58] loss=3.38 avg=3.53
# [10 | 15.59] loss=3.30 avg=3.51
# [11 | 16.54] loss=3.16 avg=3.47
# [12 | 17.47] loss=3.25 avg=3.45
# [13 | 18.40] loss=3.57 avg=3.46
# [14 | 19.33] loss=3.31 avg=3.45
# [15 | 20.28] loss=3.48 avg=3.45
# [16 | 21.30] loss=3.37 avg=3.45
# [17 | 22.32] loss=3.23 avg=3.43
# [18 | 23.32] loss=3.20 avg=3.42
# [19 | 24.28] loss=3.20 avg=3.41
# [20 | 25.22] loss=3.31 avg=3.40
# [21 | 26.15] loss=3.32 avg=3.40
# [22 | 27.09] loss=3.07 avg=3.38
# ...

# %% [markdown]
# <font color='red'> trump may be overfit </font>

# %% [markdown]
# # Elon Musk

# %%
gpt2.reset_session(sess)
file_name = "elon.txt"
run_name = "run_elon"

# %%
sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
              file_name,
              run_name = run_name,
              model_name=model_name,
              steps=1000)   # steps is max number of training steps

gpt2.generate(sess)
# Out:
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00,  1.82it/s]
# dataset has 92579 tokens
# Training...
# [1 | 6.22] loss=4.11 avg=4.11
# [2 | 7.17] loss=4.06 avg=4.08
# [3 | 8.11] loss=3.96 avg=4.04
# [4 | 9.04] loss=3.87 avg=4.00
# [5 | 9.99] loss=4.00 avg=4.00
# [6 | 10.92] loss=3.81 avg=3.97
# [7 | 11.94] loss=3.74 avg=3.93
# [8 | 12.90] loss=3.86 avg=3.92
# [9 | 13.88] loss=3.69 avg=3.90
# [10 | 14.81] loss=3.71 avg=3.88
# [11 | 15.79] loss=3.72 avg=3.86
# [12 | 16.77] loss=3.75 avg=3.85
# [13 | 17.72] loss=3.69 avg=3.84
# [14 | 18.66] loss=3.69 avg=3.83
# [15 | 19.63] loss=3.62 avg=3.81
# [16 | 20.56] loss=3.67 avg=3.80
# [17 | 21.59] loss=3.49 avg=3.78
# [18 | 22.61] loss=3.48 avg=3.76
# [19 | 23.61] loss=3.37 avg=3.74
# [20 | 24.60] loss=3.58 avg=3.73
# [21 | 25.63] loss=3.65 avg=3.73
# [22 | 26.65] loss=3.56 avg=3.72
# ...

# %% [markdown]
# # Neil Degrasse Tyson

# %%
gpt2.reset_session(sess)
file_name = "tyson.txt"
run_name = "run_tyson"

# %%
sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
              file_name,
              run_name = run_name,
              model_name=model_name,
              steps=1000)   # steps is max number of training steps

gpt2.generate(sess)
# Out:
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:01<00:00,  1.10s/it]
# dataset has 206634 tokens
# Training...
# [1 | 6.01] loss=4.05 avg=4.05
# [2 | 6.94] loss=3.71 avg=3.88
# [3 | 7.86] loss=3.47 avg=3.74
# [4 | 8.79] loss=3.44 avg=3.67
# [5 | 9.72] loss=3.94 avg=3.72
# [6 | 10.64] loss=3.48 avg=3.68
# [7 | 11.56] loss=3.47 avg=3.65
# [8 | 12.49] loss=4.00 avg=3.70
# [9 | 13.42] loss=3.62 avg=3.69
# [10 | 14.35] loss=3.43 avg=3.66
# [11 | 15.27] loss=3.77 avg=3.67
# [12 | 16.20] loss=3.67 avg=3.67
# [13 | 17.13] loss=3.47 avg=3.65
# [14 | 18.06] loss=3.59 avg=3.65
# [15 | 18.98] loss=3.15 avg=3.61
# [16 | 19.91] loss=3.34 avg=3.60
# [17 | 20.84] loss=3.34 avg=3.58
# [18 | 21.76] loss=3.21 avg=3.56
# [19 | 22.68] loss=3.46 avg=3.55
# [20 | 23.61] loss=3.32 avg=3.54
# [21 | 24.54] loss=3.61 avg=3.54
# [22 | 25.47] loss=3.54 avg=3.54
# ...

# %% [markdown]
# # 2016 Presidential Debate

# %%
gpt2.reset_session(sess)
file_name = "debate.txt"
run_name = "run_debate"

# %%
sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
              file_name,
              run_name = run_name,
              model_name=model_name,
              steps=1000)   # steps is max number of training steps

gpt2.generate(sess)
# Out:
# WARNING:tensorflow:From /home/watson/anaconda3/lib/python3.7/site-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Loading checkpoint checkpoint/run_debate/model-748
# INFO:tensorflow:Restoring parameters from checkpoint/run_debate/model-748
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00,  2.45it/s]
# dataset has 84272 tokens
# Training...
# [749 | 6.80] loss=0.05 avg=0.05
# [750 | 7.78] loss=0.05 avg=0.05
# [751 | 8.79] loss=0.06 avg=0.05
# [752 | 9.80] loss=0.05 avg=0.05
# [753 | 10.80] loss=0.04 avg=0.05
# [754 | 11.79] loss=0.05 avg=0.05
# [755 | 12.77] loss=0.05 avg=0.05
# [756 | 13.70] loss=0.06 avg=0.05
# [757 | 14.68] loss=0.05 avg=0.05
# [758 | 15.65] loss=0.05 avg=0.05
# [759 | 16.65] loss=0.06 avg=0.05
# ...

# %% [markdown]
# ## Jokes

# %%
gpt2.reset_session(sess)
file_name = "jokes.txt"
run_name = "run_jokes"

# %%
sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
              file_name,
              run_name = run_name,
              model_name=model_name,
              steps=200)   # steps is max number of training steps

gpt2.generate(sess)
# Out:
# Loading checkpoint checkpoint/run_jokes/model-200
# INFO:tensorflow:Restoring parameters from checkpoint/run_jokes/model-200
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:03<00:00,  3.94s/it]
# dataset has 953263 tokens
# Training...
# ======== SAMPLE 1 ========
#  cartridge'
# 'How can a woman beat her husband?'... 'By banging her husband for a long period of time.'
# 'Where does a blonde go when she hits puberty?'... 'To a clinic'
# "Q: Why don't women get circumcised?"... 'A: They can't stop trying!'
# 'How did Hitler know how long a rabbit had to wait before eating?'... 'he waited all day.'
# 'Did you find this joke racist?'... "I'll tell you what you think."
# 'What did the bird say when he saw a bunch of guys on a cliff?'... 'Hoop Hoop!'
# 'What did the dog walk into?'... 'A wag'
# "Why can't you tell the difference between your girlfriend and your wife?"... "Your girlfriend doesn't fart when you blow."
# ...

# %% [markdown]
# ## Song Lyrics

# %%
gpt2.reset_session(sess)
file_name = "lyrics.txt"
run_name = "run_lyrics"

# %%
sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
              file_name,
              run_name = run_name,
              model_name=model_name,
              steps=1000)   # steps is max number of training steps

gpt2.generate(sess)
# Out:
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [01:13<00:00, 73.90s/it]
# dataset has 23134899 tokens
# Training...
# [1 | 6.26] loss=2.23 avg=2.23
# [2 | 7.21] loss=3.31 avg=2.78
# [3 | 8.15] loss=2.40 avg=2.65
# [4 | 9.09] loss=2.30 avg=2.56
# [5 | 10.02] loss=2.60 avg=2.57
# [6 | 10.96] loss=2.58 avg=2.57
# [7 | 11.90] loss=2.25 avg=2.53
# [8 | 12.83] loss=2.42 avg=2.51
# [9 | 13.77] loss=2.41 avg=2.50
# [10 | 14.77] loss=2.26 avg=2.47
# [11 | 15.71] loss=2.34 avg=2.46
# [12 | 16.65] loss=2.29 avg=2.45
# [13 | 17.58] loss=2.27 avg=2.43
# [14 | 18.52] loss=2.30 avg=2.42
# [15 | 19.46] loss=2.48 avg=2.43
# [16 | 20.39] loss=1.95 avg=2.39
# [17 | 21.33] loss=2.04 avg=2.37
# [18 | 22.27] loss=2.25 avg=2.36
# [19 | 23.21] loss=2.10 avg=2.35
# [20 | 24.15] loss=2.08 avg=2.33
# [21 | 25.08] loss=2.26 avg=2.33
# [22 | 26.02] loss=2.28 avg=2.33
# ...

# %% [markdown]
# ## Movie Scripts

# %%
gpt2.reset_session(sess)
file_name = "qtscripts.txt"
run_name = "run_qtmovies"

# %%
sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
              file_name,
              run_name = run_name,
              model_name=model_name,
              steps=1000)   # steps is max number of training steps

gpt2.generate(sess)
# Out:
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00,  1.08it/s]
# dataset has 320575 tokens
# Training...
# [1 | 6.02] loss=1.87 avg=1.87
# [2 | 6.99] loss=1.75 avg=1.81
# [3 | 7.97] loss=1.75 avg=1.79
# [4 | 8.94] loss=1.87 avg=1.81
# [5 | 9.92] loss=1.88 avg=1.82
# [6 | 10.89] loss=1.69 avg=1.80
# [7 | 11.82] loss=1.70 avg=1.79
# [8 | 12.76] loss=1.82 avg=1.79
# [9 | 13.73] loss=1.67 avg=1.78
# [10 | 14.69] loss=1.63 avg=1.76
# [11 | 15.62] loss=1.55 avg=1.74
# [12 | 16.54] loss=1.41 avg=1.71
# [13 | 17.48] loss=1.40 avg=1.69
# [14 | 18.41] loss=1.37 avg=1.66
# [15 | 19.33] loss=1.49 avg=1.65
# [16 | 20.26] loss=1.58 avg=1.65
# [17 | 21.20] loss=1.47 avg=1.63
# [18 | 22.13] loss=1.75 avg=1.64
# [19 | 23.06] loss=1.94 avg=1.66
# [20 | 23.99] loss=1.25 avg=1.64
# [21 | 24.92] loss=1.49 avg=1.63
# [22 | 25.86] loss=1.60 avg=1.63
# ...

# %%
sess.close()
